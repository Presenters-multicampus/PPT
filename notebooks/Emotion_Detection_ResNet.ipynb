# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Input
from keras.preprocessing.image import ImageDataGenerator
import os
from keras.models import Sequential, Model
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers.advanced_activations import ELU
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras.optimizers import RMSprop, SGD, Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras import regularizers
from keras.regularizers import l1, l2
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
# Out:
# Using TensorFlow backend.
# /home/KTH/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/KTH/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/KTH/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/KTH/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/KTH/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/KTH/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/KTH/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/KTH/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/KTH/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/KTH/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/KTH/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/KTH/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
num_classes = 7
img_rows, img_cols = 48, 48
batch_size = 32
epochs = 200

train_data_dir = '../fer2013/train'
validation_data_dir = '../fer2013/validation'

val_datagen = ImageDataGenerator(rescale=1./255)
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 30,
    shear_range = 0.3,
    zoom_range = 0.3,
    horizontal_flip = True,
    fill_mode = 'nearest'
)

train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
print(validation_generator.class_indices)
# Out:
# {'Angry': 0, 'Disgust': 1, 'Fear': 2, 'Happy': 3, 'Neutral': 4, 'Sad': 5, 'Surprise': 6}

# %%
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr * 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                num_filters=16,
                kernel_size=3,
                strides=1,
                activation='relu',
                batch_normalization=True,
                conv_first=True):
    conv = Conv2D(num_filters,
                 kernel_size=strides,
                 padding='same',
                 kernel_initializer='he_normal',
                 kernel_regularizer=l2(1e-4))
    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v2(input_shape, depth, num_classes=7):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
    input_shape (tensor): shape of input image tensor
    depth (int): number of core convolutional layers
    num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
    model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
        
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)
    
    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs,
                    num_filters=num_filters_in,
                    conv_first=True)
    
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            # num of param setting 
            if stage == 0: # first stage
                num_filters_out = num_filters_in * 4
                if res_block == 0: # first layer & first stage
                    activation = None
                    batch_normalization = False
            else: # second, third stage
                num_filters_out = num_filters_in * 2
                if res_block == 0: # first layer but no first stage
                    strides = 2 # downsample
            y = resnet_layer(inputs=x,
                            num_filters=num_filters_in,
                            kernel_size=1,
                            strides=strides,
                            activation=activation,
                            batch_normalization=batch_normalization,
                            conv_first=False)
            y = resnet_layer(inputs=y,
                            num_filters=num_filters_in,
                            conv_first=False)
            y = resnet_layer(inputs=y,
                            num_filters=num_filters_out,
                            kernel_size=1,
                            conv_first=False)
            if res_block == 0:
                # Linear projection residual shortcut connection to match
                # changed dims
                # at the first time, make a shortcut origin
                x = resnet_layer(inputs=x,
                                num_filters=num_filters_out,
                                kernel_size=1,
                                strides=strides,
                                activation=None,
                                batch_normalization=False)
            # and add every reputation
            x = keras.layers.add([x, y])
        
        num_filters_in = num_filters_out
    
    # Add classifier on top
    # v2 has BN_ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                   activation='softmax',
                   kernel_initializer='he_normal')(y)
    
    # Instantiate model
    model = Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
import keras.backend as K
K.clear_session()

n = 6
version = 2
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2
    
input_shape = [48,48,1]

model = resnet_v2(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
             optimizer=Adam(learning_rate=lr_schedule(0)),
             metrics=['acc'])
model.summary()
# Out:
# WARNING:tensorflow:From /home/KTH/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Learning rate:  0.001
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 48, 48, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 48, 48, 16)   32          input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 48, 48, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 48, 48, 16)   272         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 48, 48, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 48, 48, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 48, 48, 16)   272         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 48, 48, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 48, 48, 16)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 48, 48, 64)   1088        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 48, 48, 64)   1088        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 48, 48, 64)   0           conv2d_5[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 48, 48, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 48, 48, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 48, 48, 16)   1040        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 48, 48, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 48, 48, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 48, 48, 16)   272         activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 48, 48, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 48, 48, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 48, 48, 64)   1088        activation_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 48, 48, 64)   0           add_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 48, 48, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 48, 48, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 48, 48, 16)   1040        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 48, 48, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 48, 48, 16)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 48, 48, 16)   272         activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 48, 48, 16)   64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 48, 48, 16)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 48, 48, 64)   1088        activation_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 48, 48, 64)   0           add_2[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 48, 48, 64)   256         add_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 48, 48, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 48, 48, 16)   1040        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 48, 48, 16)   64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 48, 48, 16)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 48, 48, 16)   272         activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 48, 48, 16)   64          conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 48, 48, 16)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 48, 48, 64)   1088        activation_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 48, 48, 64)   0           add_3[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 48, 48, 64)   256         add_4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 48, 48, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 48, 48, 16)   1040        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 48, 48, 16)   64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 48, 48, 16)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 48, 48, 16)   272         activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 48, 48, 16)   64          conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 48, 48, 16)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 48, 48, 64)   1088        activation_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 48, 48, 64)   0           add_4[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 48, 48, 64)   256         add_5[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 48, 48, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 48, 48, 16)   1040        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 48, 48, 16)   64          conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 48, 48, 16)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 48, 48, 16)   272         activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 48, 48, 16)   64          conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 48, 48, 16)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 48, 48, 64)   1088        activation_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 48, 48, 64)   0           add_5[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 48, 48, 64)   256         add_6[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 48, 48, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 48, 48, 64)   16448       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 48, 48, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 48, 48, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 48, 48, 64)   4160        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 48, 48, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 48, 48, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 48, 48, 128)  32896       add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 48, 48, 128)  8320        activation_21[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 48, 48, 128)  0           conv2d_24[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 48, 48, 128)  512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 48, 48, 128)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 48, 48, 64)   8256        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 48, 48, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 48, 48, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 48, 48, 64)   4160        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 48, 48, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 48, 48, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 48, 48, 128)  8320        activation_24[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 48, 48, 128)  0           add_7[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 48, 48, 128)  512         add_8[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 48, 48, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 48, 48, 64)   8256        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 48, 48, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 48, 48, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 48, 48, 64)   4160        activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 48, 48, 64)   256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 48, 48, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 48, 48, 128)  8320        activation_27[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 48, 48, 128)  0           add_8[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 48, 48, 128)  512         add_9[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 48, 48, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 48, 48, 64)   8256        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 48, 48, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 48, 48, 64)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 48, 48, 64)   4160        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 48, 48, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 48, 48, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 48, 48, 128)  8320        activation_30[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 48, 48, 128)  0           add_9[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 48, 48, 128)  512         add_10[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 48, 48, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 48, 48, 64)   8256        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 48, 48, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 48, 48, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 48, 48, 64)   4160        activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 48, 48, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 48, 48, 64)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 48, 48, 128)  8320        activation_33[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 48, 48, 128)  0           add_10[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 48, 48, 128)  512         add_11[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 48, 48, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 48, 48, 64)   8256        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 48, 48, 64)   256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 48, 48, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 48, 48, 64)   4160        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 48, 48, 64)   256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 48, 48, 64)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 48, 48, 128)  8320        activation_36[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 48, 48, 128)  0           add_11[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 48, 48, 128)  512         add_12[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 48, 48, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 48, 48, 128)  65664       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 48, 48, 128)  512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 48, 48, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 48, 48, 128)  16512       activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 48, 48, 128)  512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 48, 48, 128)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 48, 48, 256)  131328      add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 48, 48, 256)  33024       activation_39[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 48, 48, 256)  0           conv2d_43[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 48, 48, 256)  1024        add_13[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 48, 48, 256)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 48, 48, 128)  32896       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 48, 48, 128)  512         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 48, 48, 128)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 48, 48, 128)  16512       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 48, 48, 128)  512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 48, 48, 128)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 48, 48, 256)  33024       activation_42[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 48, 48, 256)  0           add_13[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 48, 48, 256)  1024        add_14[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 48, 48, 256)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 48, 48, 128)  32896       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 48, 48, 128)  512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 48, 48, 128)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 48, 48, 128)  16512       activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 48, 48, 128)  512         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 48, 48, 128)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 48, 48, 256)  33024       activation_45[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 48, 48, 256)  0           add_14[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 48, 48, 256)  1024        add_15[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 48, 48, 256)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 48, 48, 128)  32896       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 48, 48, 128)  512         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 48, 48, 128)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 48, 48, 128)  16512       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 48, 48, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 48, 48, 128)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 48, 48, 256)  33024       activation_48[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 48, 48, 256)  0           add_15[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 48, 48, 256)  1024        add_16[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 48, 48, 256)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 48, 48, 128)  32896       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 48, 48, 128)  512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 48, 48, 128)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 48, 48, 128)  16512       activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 48, 48, 128)  512         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 48, 48, 128)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 48, 48, 256)  33024       activation_51[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 48, 48, 256)  0           add_16[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 48, 48, 256)  1024        add_17[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 48, 48, 256)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 48, 48, 128)  32896       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 48, 48, 128)  512         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 48, 48, 128)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 48, 48, 128)  16512       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 48, 48, 128)  512         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 48, 48, 128)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 48, 48, 256)  33024       activation_54[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 48, 48, 256)  0           add_17[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 48, 48, 256)  1024        add_18[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 48, 48, 256)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 6, 6, 256)    0           activation_55[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 9216)         0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 7)            64519       flatten_1[0][0]
# ==================================================================================================
# Total params: 924,263
# Trainable params: 913,863
# Non-trainable params: 10,400
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train

# %%
dataset = pd.read_csv('../Sample_Pic_OD/fer2013.csv')
train = dataset[['emotion','pixels']][:28709]
val = dataset[['emotion','pixels']][28709:]

# %%
filepath = os.path.join('../emotion_detector_models/model_resnet_best.hdf5')

nb_train_samples = train.shape[0]
nb_validation_samples = val.shape[0]

checkpoint = ModelCheckpoint(filepath=filepath,
                            monitor='val_acc',
                            verbose=1,
                            save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_scheduler, lr_reducer]

model_info = model.fit_generator(
            train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=nb_validation_samples // batch_size)
# Out:
# WARNING:tensorflow:From /home/KTH/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/200
# Learning rate:  0.001
# 897/897 [==============================] - 196s 219ms/step - loss: 2.6561 - acc: 0.2708 - val_loss: 2.2533 - val_acc: 0.3221
#
# Epoch 00001: val_acc improved from -inf to 0.32213, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 2/200
# Learning rate:  0.001
# 897/897 [==============================] - 178s 199ms/step - loss: 2.0388 - acc: 0.3300 - val_loss: 1.8546 - val_acc: 0.3784
#
# Epoch 00002: val_acc improved from 0.32213 to 0.37839, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 3/200
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.8328 - acc: 0.3606 - val_loss: 1.7412 - val_acc: 0.4092
#
# Epoch 00003: val_acc improved from 0.37839 to 0.40918, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 4/200
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.7560 - acc: 0.3732 - val_loss: 1.6695 - val_acc: 0.4134
#
# Epoch 00004: val_acc improved from 0.40918 to 0.41338, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 5/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.7003 - acc: 0.3840 - val_loss: 1.4435 - val_acc: 0.3987
#
# Epoch 00005: val_acc did not improve from 0.41338
# Epoch 6/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.6702 - acc: 0.3887 - val_loss: 1.6203 - val_acc: 0.4274
#
# Epoch 00006: val_acc improved from 0.41338 to 0.42737, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 7/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.6350 - acc: 0.4019 - val_loss: 1.5636 - val_acc: 0.4313
#
# Epoch 00007: val_acc improved from 0.42737 to 0.43129, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 8/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.6131 - acc: 0.4099 - val_loss: 1.5110 - val_acc: 0.4479
#
# Epoch 00008: val_acc improved from 0.43129 to 0.44794, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 9/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.5842 - acc: 0.4210 - val_loss: 1.4652 - val_acc: 0.4577
#
# Epoch 00009: val_acc improved from 0.44794 to 0.45774, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 10/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.5640 - acc: 0.4310 - val_loss: 1.4435 - val_acc: 0.4481
#
# Epoch 00010: val_acc did not improve from 0.45774
# Epoch 11/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.5442 - acc: 0.4340 - val_loss: 1.5666 - val_acc: 0.4512
#
# Epoch 00011: val_acc did not improve from 0.45774
# Epoch 12/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.5191 - acc: 0.4458 - val_loss: 1.5550 - val_acc: 0.4507
#
# Epoch 00012: val_acc did not improve from 0.45774
# Epoch 13/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.5050 - acc: 0.4513 - val_loss: 1.5594 - val_acc: 0.4645
#
# Epoch 00013: val_acc improved from 0.45774 to 0.46446, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 14/200
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.4959 - acc: 0.4538 - val_loss: 1.4841 - val_acc: 0.4842
#
# Epoch 00014: val_acc improved from 0.46446 to 0.48419, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 15/200
# Learning rate:  0.001
# 897/897 [==============================] - 178s 199ms/step - loss: 1.4793 - acc: 0.4619 - val_loss: 1.2416 - val_acc: 0.4926
#
# Epoch 00015: val_acc improved from 0.48419 to 0.49258, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 16/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.4637 - acc: 0.4658 - val_loss: 1.1704 - val_acc: 0.4772
#
# Epoch 00016: val_acc did not improve from 0.49258
# Epoch 17/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.4558 - acc: 0.4684 - val_loss: 1.4581 - val_acc: 0.4861
#
# Epoch 00017: val_acc did not improve from 0.49258
# Epoch 18/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.4433 - acc: 0.4713 - val_loss: 1.5504 - val_acc: 0.5003
#
# Epoch 00018: val_acc improved from 0.49258 to 0.50028, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 19/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.4349 - acc: 0.4745 - val_loss: 1.3657 - val_acc: 0.4815
#
# Epoch 00019: val_acc did not improve from 0.50028
# Epoch 20/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.4228 - acc: 0.4830 - val_loss: 1.4466 - val_acc: 0.4575
#
# Epoch 00020: val_acc did not improve from 0.50028
# Epoch 21/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.4196 - acc: 0.4816 - val_loss: 1.5144 - val_acc: 0.5034
#
# Epoch 00021: val_acc improved from 0.50028 to 0.50336, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 22/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.4133 - acc: 0.4822 - val_loss: 1.2571 - val_acc: 0.4919
#
# Epoch 00022: val_acc did not improve from 0.50336
# Epoch 23/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.4029 - acc: 0.4853 - val_loss: 1.5235 - val_acc: 0.4618
#
# Epoch 00023: val_acc did not improve from 0.50336
# Epoch 24/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.4006 - acc: 0.4913 - val_loss: 1.3465 - val_acc: 0.5024
#
# Epoch 00024: val_acc did not improve from 0.50336
# Epoch 25/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3926 - acc: 0.4897 - val_loss: 1.3870 - val_acc: 0.4854
#
# Epoch 00025: val_acc did not improve from 0.50336
# Epoch 26/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3921 - acc: 0.4954 - val_loss: 1.6487 - val_acc: 0.4975
#
# Epoch 00026: val_acc did not improve from 0.50336
# Epoch 27/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.3790 - acc: 0.4942 - val_loss: 1.3538 - val_acc: 0.4983
#
# Epoch 00027: val_acc did not improve from 0.50336
# Epoch 28/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3768 - acc: 0.4975 - val_loss: 1.1229 - val_acc: 0.4959
#
# Epoch 00028: val_acc did not improve from 0.50336
# Epoch 29/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.3754 - acc: 0.5009 - val_loss: 1.3777 - val_acc: 0.5178
#
# Epoch 00029: val_acc improved from 0.50336 to 0.51777, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 30/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3654 - acc: 0.5022 - val_loss: 1.2869 - val_acc: 0.5027
#
# Epoch 00030: val_acc did not improve from 0.51777
# Epoch 31/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3629 - acc: 0.5057 - val_loss: 1.2839 - val_acc: 0.4994
#
# Epoch 00031: val_acc did not improve from 0.51777
# Epoch 32/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.3616 - acc: 0.5071 - val_loss: 1.1525 - val_acc: 0.5132
#
# Epoch 00032: val_acc did not improve from 0.51777
# Epoch 33/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3544 - acc: 0.5058 - val_loss: 1.4830 - val_acc: 0.5049
#
# Epoch 00033: val_acc did not improve from 0.51777
# Epoch 34/200
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.3562 - acc: 0.5089 - val_loss: 1.4679 - val_acc: 0.5141
#
# Epoch 00034: val_acc did not improve from 0.51777
# Epoch 35/200
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.3575 - acc: 0.5058 - val_loss: 1.2353 - val_acc: 0.5034
#
# Epoch 00035: val_acc did not improve from 0.51777
# Epoch 36/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3489 - acc: 0.5085 - val_loss: 1.1699 - val_acc: 0.5157
#
# Epoch 00036: val_acc did not improve from 0.51777
# Epoch 37/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3429 - acc: 0.5120 - val_loss: 1.1800 - val_acc: 0.5035
#
# Epoch 00037: val_acc did not improve from 0.51777
# Epoch 38/200
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.3393 - acc: 0.5088 - val_loss: 1.4275 - val_acc: 0.5157
#
# Epoch 00038: val_acc did not improve from 0.51777
# Epoch 39/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3367 - acc: 0.5108 - val_loss: 1.3913 - val_acc: 0.5234
#
# Epoch 00039: val_acc improved from 0.51777 to 0.52337, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 40/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3324 - acc: 0.5140 - val_loss: 1.4749 - val_acc: 0.5270
#
# Epoch 00040: val_acc improved from 0.52337 to 0.52701, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 41/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3329 - acc: 0.5165 - val_loss: 1.2347 - val_acc: 0.5134
#
# Epoch 00041: val_acc did not improve from 0.52701
# Epoch 42/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.3263 - acc: 0.5165 - val_loss: 1.3138 - val_acc: 0.5218
#
# Epoch 00042: val_acc did not improve from 0.52701
# Epoch 43/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3252 - acc: 0.5196 - val_loss: 1.3970 - val_acc: 0.5216
#
# Epoch 00043: val_acc did not improve from 0.52701
# Epoch 44/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3201 - acc: 0.5221 - val_loss: 1.0709 - val_acc: 0.5302
#
# Epoch 00044: val_acc improved from 0.52701 to 0.53023, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 45/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3210 - acc: 0.5208 - val_loss: 0.8808 - val_acc: 0.5271
#
# Epoch 00045: val_acc did not improve from 0.53023
# Epoch 46/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3191 - acc: 0.5195 - val_loss: 1.3305 - val_acc: 0.5326
#
# Epoch 00046: val_acc improved from 0.53023 to 0.53261, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 47/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3171 - acc: 0.5180 - val_loss: 1.0537 - val_acc: 0.5376
#
# Epoch 00047: val_acc improved from 0.53261 to 0.53764, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 48/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3133 - acc: 0.5214 - val_loss: 1.4097 - val_acc: 0.5255
#
# Epoch 00048: val_acc did not improve from 0.53764
# Epoch 49/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3085 - acc: 0.5239 - val_loss: 1.3386 - val_acc: 0.5263
#
# Epoch 00049: val_acc did not improve from 0.53764
# Epoch 50/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3069 - acc: 0.5261 - val_loss: 1.6462 - val_acc: 0.5264
#
# Epoch 00050: val_acc did not improve from 0.53764
# Epoch 51/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3039 - acc: 0.5274 - val_loss: 1.5004 - val_acc: 0.5049
#
# Epoch 00051: val_acc did not improve from 0.53764
# Epoch 52/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3024 - acc: 0.5279 - val_loss: 0.9751 - val_acc: 0.5383
#
# Epoch 00052: val_acc improved from 0.53764 to 0.53834, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 53/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.3069 - acc: 0.5277 - val_loss: 1.3539 - val_acc: 0.5192
#
# Epoch 00053: val_acc did not improve from 0.53834
# Epoch 54/200
# Learning rate:  0.001
# 897/897 [==============================] - 177s 197ms/step - loss: 1.2963 - acc: 0.5298 - val_loss: 1.2894 - val_acc: 0.5350
#
# Epoch 00054: val_acc did not improve from 0.53834
# Epoch 55/200
# Learning rate:  0.001
# 723/897 [=======================>......] - ETA: 31s - loss: 1.2974 - acc: 0.5293

# %% [markdown]
# ## Restore and Retrain

# %%
model.load_weights('../emotion_detector_models/model_resnet_best.hdf5')

epochs=100

filepath = os.path.join('../emotion_detector_models/model_resnet_best.hdf5')

nb_train_samples = train.shape[0]
nb_validation_samples = val.shape[0]

checkpoint = ModelCheckpoint(filepath=filepath,
                            monitor='val_acc',
                            verbose=1,
                            save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_scheduler, lr_reducer]

model_info = model.fit_generator(
            train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=nb_validation_samples // batch_size)
# Out:
# WARNING:tensorflow:From /home/KTH/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
# Learning rate:  0.001
# 897/897 [==============================] - 193s 215ms/step - loss: 1.3000 - acc: 0.5278 - val_loss: 1.3391 - val_acc: 0.5181
#
# Epoch 00001: val_acc improved from -inf to 0.51814, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 2/100
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.2999 - acc: 0.5284 - val_loss: 1.6360 - val_acc: 0.5199
#
# Epoch 00002: val_acc improved from 0.51814 to 0.51987, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 3/100
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.2977 - acc: 0.5266 - val_loss: 1.5438 - val_acc: 0.5280
#
# Epoch 00003: val_acc improved from 0.51987 to 0.52799, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 4/100
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.2955 - acc: 0.5301 - val_loss: 1.7732 - val_acc: 0.5250
#
# Epoch 00004: val_acc did not improve from 0.52799
# Epoch 5/100
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.2935 - acc: 0.5298 - val_loss: 1.1470 - val_acc: 0.5432
#
# Epoch 00005: val_acc improved from 0.52799 to 0.54324, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 6/100
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.2986 - acc: 0.5294 - val_loss: 1.3530 - val_acc: 0.5209
#
# Epoch 00006: val_acc did not improve from 0.54324
# Epoch 7/100
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.2896 - acc: 0.5327 - val_loss: 1.2733 - val_acc: 0.5290
#
# Epoch 00007: val_acc did not improve from 0.54324
# Epoch 8/100
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.2911 - acc: 0.5294 - val_loss: 1.2412 - val_acc: 0.5341
#
# Epoch 00008: val_acc did not improve from 0.54324
# Epoch 9/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2820 - acc: 0.5325 - val_loss: 1.1669 - val_acc: 0.5262
#
# Epoch 00009: val_acc did not improve from 0.54324
# Epoch 10/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2863 - acc: 0.5325 - val_loss: 1.4552 - val_acc: 0.5353
#
# Epoch 00010: val_acc did not improve from 0.54324
# Epoch 11/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2783 - acc: 0.5357 - val_loss: 1.4726 - val_acc: 0.5283
#
# Epoch 00011: val_acc did not improve from 0.54324
# Epoch 12/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2865 - acc: 0.5339 - val_loss: 1.2078 - val_acc: 0.5425
#
# Epoch 00012: val_acc did not improve from 0.54324
# Epoch 13/100
# Learning rate:  0.001
# 897/897 [==============================] - 178s 199ms/step - loss: 1.2858 - acc: 0.5316 - val_loss: 1.4012 - val_acc: 0.5344
#
# Epoch 00013: val_acc did not improve from 0.54324
# Epoch 14/100
# Learning rate:  0.001
# 897/897 [==============================] - 179s 199ms/step - loss: 1.2833 - acc: 0.5338 - val_loss: 1.1087 - val_acc: 0.5361
#
# Epoch 00014: val_acc did not improve from 0.54324
# Epoch 15/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2767 - acc: 0.5334 - val_loss: 1.8276 - val_acc: 0.5190
#
# Epoch 00015: val_acc did not improve from 0.54324
# Epoch 16/100
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.2818 - acc: 0.5310 - val_loss: 1.3623 - val_acc: 0.5308
#
# Epoch 00016: val_acc did not improve from 0.54324
# Epoch 17/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2742 - acc: 0.5397 - val_loss: 1.1961 - val_acc: 0.5407
#
# Epoch 00017: val_acc did not improve from 0.54324
# Epoch 18/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2742 - acc: 0.5343 - val_loss: 1.4236 - val_acc: 0.5392
#
# Epoch 00018: val_acc did not improve from 0.54324
# Epoch 19/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2712 - acc: 0.5434 - val_loss: 1.8128 - val_acc: 0.5167
#
# Epoch 00019: val_acc did not improve from 0.54324
# Epoch 20/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2714 - acc: 0.5386 - val_loss: 1.1997 - val_acc: 0.5354
#
# Epoch 00020: val_acc did not improve from 0.54324
# Epoch 21/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2676 - acc: 0.5384 - val_loss: 1.2845 - val_acc: 0.5327
#
# Epoch 00021: val_acc did not improve from 0.54324
# Epoch 22/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2698 - acc: 0.5412 - val_loss: 1.4318 - val_acc: 0.5334
#
# Epoch 00022: val_acc did not improve from 0.54324
# Epoch 23/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2646 - acc: 0.5429 - val_loss: 1.3160 - val_acc: 0.5379
#
# Epoch 00023: val_acc did not improve from 0.54324
# Epoch 24/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2634 - acc: 0.5417 - val_loss: 1.5054 - val_acc: 0.5469
#
# Epoch 00024: val_acc improved from 0.54324 to 0.54688, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 25/100
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.2687 - acc: 0.5392 - val_loss: 1.0180 - val_acc: 0.5404
#
# Epoch 00025: val_acc did not improve from 0.54688
# Epoch 26/100
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.2643 - acc: 0.5399 - val_loss: 1.2022 - val_acc: 0.5458
#
# Epoch 00026: val_acc did not improve from 0.54688
# Epoch 27/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2666 - acc: 0.5387 - val_loss: 1.2590 - val_acc: 0.5414
#
# Epoch 00027: val_acc did not improve from 0.54688
# Epoch 28/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2603 - acc: 0.5430 - val_loss: 1.2700 - val_acc: 0.5470
#
# Epoch 00028: val_acc improved from 0.54688 to 0.54702, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 29/100
# Learning rate:  0.001
# 897/897 [==============================] - 177s 198ms/step - loss: 1.2572 - acc: 0.5493 - val_loss: 1.3904 - val_acc: 0.5417
#
# Epoch 00029: val_acc did not improve from 0.54702
# Epoch 30/100
# Learning rate:  0.001
# 897/897 [==============================] - 178s 198ms/step - loss: 1.2606 - acc: 0.5447 - val_loss: 1.4858 - val_acc: 0.5490
#
# Epoch 00030: val_acc improved from 0.54702 to 0.54898, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 31/100
# Learning rate:  0.001
# 897/897 [==============================] - 179s 199ms/step - loss: 1.2618 - acc: 0.5439 - val_loss: 1.3051 - val_acc: 0.5236
#
# Epoch 00031: val_acc did not improve from 0.54898
# Epoch 32/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 200ms/step - loss: 1.2661 - acc: 0.5425 - val_loss: 0.9534 - val_acc: 0.5271
#
# Epoch 00032: val_acc did not improve from 0.54898
# Epoch 33/100
# Learning rate:  0.001
# 897/897 [==============================] - 178s 199ms/step - loss: 1.2544 - acc: 0.5471 - val_loss: 1.4443 - val_acc: 0.5319
#
# Epoch 00033: val_acc did not improve from 0.54898
# Epoch 34/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2564 - acc: 0.5438 - val_loss: 1.3841 - val_acc: 0.5260
#
# Epoch 00034: val_acc did not improve from 0.54898
# Epoch 35/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 200ms/step - loss: 1.2543 - acc: 0.5489 - val_loss: 1.1232 - val_acc: 0.5319
#
# Epoch 00035: val_acc did not improve from 0.54898
# Epoch 36/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 200ms/step - loss: 1.2568 - acc: 0.5414 - val_loss: 1.1577 - val_acc: 0.5298
# Epoch 00036: val_acc did not improve from 0.54898
# Epoch 37/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2516 - acc: 0.5459 - val_loss: 1.6575 - val_acc: 0.5526
#
# Epoch 00037: val_acc improved from 0.54898 to 0.55262, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 38/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 200ms/step - loss: 1.2569 - acc: 0.5444 - val_loss: 1.2001 - val_acc: 0.5554
#
# Epoch 00038: val_acc improved from 0.55262 to 0.55542, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 39/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2515 - acc: 0.5449 - val_loss: 1.1212 - val_acc: 0.5399
#
# Epoch 00039: val_acc did not improve from 0.55542
# Epoch 40/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2466 - acc: 0.5484 - val_loss: 1.0311 - val_acc: 0.5395
#
# Epoch 00040: val_acc did not improve from 0.55542
# Epoch 41/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2469 - acc: 0.5472 - val_loss: 1.3965 - val_acc: 0.5409
#
# Epoch 00041: val_acc did not improve from 0.55542
# Epoch 42/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2475 - acc: 0.5462 - val_loss: 1.4717 - val_acc: 0.5148
#
# Epoch 00042: val_acc did not improve from 0.55542
# Epoch 43/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2492 - acc: 0.5472 - val_loss: 1.5990 - val_acc: 0.5182
#
# Epoch 00043: val_acc did not improve from 0.55542
# Epoch 44/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2417 - acc: 0.5492 - val_loss: 0.8613 - val_acc: 0.5304
#
# Epoch 00044: val_acc did not improve from 0.55542
# Epoch 45/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2495 - acc: 0.5485 - val_loss: 1.5510 - val_acc: 0.5388
#
# Epoch 00045: val_acc did not improve from 0.55542
# Epoch 46/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2443 - acc: 0.5514 - val_loss: 1.1509 - val_acc: 0.5486
#
# Epoch 00046: val_acc did not improve from 0.55542
# Epoch 47/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2461 - acc: 0.5474 - val_loss: 1.0486 - val_acc: 0.5348
#
# Epoch 00047: val_acc did not improve from 0.55542
# Epoch 48/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2456 - acc: 0.5478 - val_loss: 1.1092 - val_acc: 0.5509
#
# Epoch 00048: val_acc did not improve from 0.55542
# Epoch 49/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2435 - acc: 0.5490 - val_loss: 1.3172 - val_acc: 0.5309
#
# Epoch 00049: val_acc did not improve from 0.55542
# Epoch 50/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2347 - acc: 0.5517 - val_loss: 0.9954 - val_acc: 0.5284
#
# Epoch 00050: val_acc did not improve from 0.55542
# Epoch 51/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2422 - acc: 0.5522 - val_loss: 1.2240 - val_acc: 0.5371
#
# Epoch 00051: val_acc did not improve from 0.55542
# Epoch 52/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2409 - acc: 0.5536 - val_loss: 1.3686 - val_acc: 0.5287
#
# Epoch 00052: val_acc did not improve from 0.55542
# Epoch 53/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 201ms/step - loss: 1.2389 - acc: 0.5535 - val_loss: 1.6221 - val_acc: 0.5467
#
# Epoch 00053: val_acc did not improve from 0.55542
# Epoch 54/100
# Learning rate:  0.001
# 897/897 [==============================] - 182s 203ms/step - loss: 1.2369 - acc: 0.5490 - val_loss: 1.2756 - val_acc: 0.5406
#
# Epoch 00054: val_acc did not improve from 0.55542
# Epoch 55/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2366 - acc: 0.5538 - val_loss: 1.3386 - val_acc: 0.5302
#
# Epoch 00055: val_acc did not improve from 0.55542
# Epoch 56/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2355 - acc: 0.5551 - val_loss: 1.2929 - val_acc: 0.5336
#
# Epoch 00056: val_acc did not improve from 0.55542
# Epoch 57/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2356 - acc: 0.5522 - val_loss: 1.2154 - val_acc: 0.5476
#
# Epoch 00057: val_acc did not improve from 0.55542
# Epoch 58/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2340 - acc: 0.5540 - val_loss: 1.1838 - val_acc: 0.5213
#
# Epoch 00058: val_acc did not improve from 0.55542
# Epoch 59/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2291 - acc: 0.5535 - val_loss: 1.3369 - val_acc: 0.5315
#
# Epoch 00059: val_acc did not improve from 0.55542
# Epoch 60/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2378 - acc: 0.5522 - val_loss: 1.1778 - val_acc: 0.5456
#
# Epoch 00060: val_acc did not improve from 0.55542
# Epoch 61/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2347 - acc: 0.5512 - val_loss: 1.5659 - val_acc: 0.5052
#
# Epoch 00061: val_acc did not improve from 0.55542
# Epoch 62/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2390 - acc: 0.5503 - val_loss: 1.4335 - val_acc: 0.5228
#
# Epoch 00062: val_acc did not improve from 0.55542
# Epoch 63/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 201ms/step - loss: 1.2316 - acc: 0.5546 - val_loss: 1.3615 - val_acc: 0.5364
#
# Epoch 00063: val_acc did not improve from 0.55542
# Epoch 64/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2378 - acc: 0.5530 - val_loss: 1.2598 - val_acc: 0.5397
#
# Epoch 00064: val_acc did not improve from 0.55542
# Epoch 65/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2311 - acc: 0.5549 - val_loss: 1.3330 - val_acc: 0.5299
#
# Epoch 00065: val_acc did not improve from 0.55542
# Epoch 66/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2305 - acc: 0.5557 - val_loss: 1.2670 - val_acc: 0.5308
#
# Epoch 00066: val_acc did not improve from 0.55542
# Epoch 67/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 201ms/step - loss: 1.2254 - acc: 0.5555 - val_loss: 1.1567 - val_acc: 0.5273
#
# Epoch 00067: val_acc did not improve from 0.55542
# Epoch 68/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 201ms/step - loss: 1.2286 - acc: 0.5575 - val_loss: 1.5851 - val_acc: 0.5505
#
# Epoch 00068: val_acc did not improve from 0.55542
# Epoch 69/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2274 - acc: 0.5576 - val_loss: 1.4581 - val_acc: 0.5425
#
# Epoch 00069: val_acc did not improve from 0.55542
# Epoch 70/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2291 - acc: 0.5559 - val_loss: 1.4917 - val_acc: 0.5467
#
# Epoch 00070: val_acc did not improve from 0.55542
# Epoch 71/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2256 - acc: 0.5573 - val_loss: 1.0548 - val_acc: 0.5278
#
# Epoch 00071: val_acc did not improve from 0.55542
# Epoch 72/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2334 - acc: 0.5532 - val_loss: 1.4270 - val_acc: 0.5291
#
# Epoch 00072: val_acc did not improve from 0.55542
# Epoch 73/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 202ms/step - loss: 1.2254 - acc: 0.5576 - val_loss: 1.2729 - val_acc: 0.5309
#
# Epoch 00073: val_acc did not improve from 0.55542
# Epoch 74/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 202ms/step - loss: 1.2250 - acc: 0.5578 - val_loss: 1.1557 - val_acc: 0.5316
#
# Epoch 00074: val_acc did not improve from 0.55542
# Epoch 75/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2189 - acc: 0.5600 - val_loss: 1.1187 - val_acc: 0.5406
#
# Epoch 00075: val_acc did not improve from 0.55542
# Epoch 76/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2256 - acc: 0.5574 - val_loss: 1.5972 - val_acc: 0.5585
#
# Epoch 00076: val_acc improved from 0.55542 to 0.55849, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 77/100
# Learning rate:  0.001
# 897/897 [==============================] - 182s 203ms/step - loss: 1.2262 - acc: 0.5586 - val_loss: 1.4260 - val_acc: 0.5607
#
# Epoch 00077: val_acc improved from 0.55849 to 0.56073, saving model to ../emotion_detector_models/model_resnet_best.hdf5
# Epoch 78/100
# Learning rate:  0.001
# 721/897 [=======================>......] - ETA: 32s - loss: 1.2230 - acc: 0.5586

# %% [markdown]
# ## Restore & Retrain 2

# %%
model.load_weights('../emotion_detector_models/model_resnet_best_r2.hdf5')

epochs=100

filepath = os.path.join('../emotion_detector_models/model_resnet_best_r2.hdf5')

nb_train_samples = train.shape[0]
nb_validation_samples = val.shape[0]

checkpoint = ModelCheckpoint(filepath=filepath,
                            monitor='val_acc',
                            verbose=1,
                            save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=2,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_scheduler, lr_reducer]

model_info = model.fit_generator(
            train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=nb_validation_samples // batch_size)
# Out:
# WARNING:tensorflow:From /home/KTH/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
# Learning rate:  0.001
# 897/897 [==============================] - 202s 225ms/step - loss: 1.2113 - acc: 0.5623 - val_loss: 1.5256 - val_acc: 0.5467
#
# Epoch 00001: val_acc improved from -inf to 0.54674, saving model to ../emotion_detector_models/model_resnet_best_r2.hdf5
# Epoch 2/100
# Learning rate:  0.001
# 897/897 [==============================] - 182s 203ms/step - loss: 1.2149 - acc: 0.5616 - val_loss: 1.3965 - val_acc: 0.5402
#
# Epoch 00002: val_acc did not improve from 0.54674
# Epoch 3/100
# Learning rate:  0.001
# 897/897 [==============================] - 182s 203ms/step - loss: 1.2111 - acc: 0.5600 - val_loss: 1.5045 - val_acc: 0.5570
#
# Epoch 00003: val_acc improved from 0.54674 to 0.55695, saving model to ../emotion_detector_models/model_resnet_best_r2.hdf5
# Epoch 4/100
# Learning rate:  0.001
# 897/897 [==============================] - 185s 207ms/step - loss: 1.2147 - acc: 0.5613 - val_loss: 1.5730 - val_acc: 0.5350
#
# Epoch 00004: val_acc did not improve from 0.55695
# Epoch 5/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 202ms/step - loss: 1.2106 - acc: 0.5633 - val_loss: 1.2433 - val_acc: 0.5435
#
# Epoch 00005: val_acc did not improve from 0.55695
# Epoch 6/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 202ms/step - loss: 1.2123 - acc: 0.5651 - val_loss: 1.3044 - val_acc: 0.5523
#
# Epoch 00006: val_acc did not improve from 0.55695
# Epoch 7/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 202ms/step - loss: 1.2063 - acc: 0.5649 - val_loss: 1.5450 - val_acc: 0.5493
#
# Epoch 00007: val_acc did not improve from 0.55695
# Epoch 8/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 202ms/step - loss: 1.2121 - acc: 0.5648 - val_loss: 1.2737 - val_acc: 0.5446
#
# Epoch 00008: val_acc did not improve from 0.55695
# Epoch 9/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 201ms/step - loss: 1.2121 - acc: 0.5604 - val_loss: 1.2935 - val_acc: 0.5383
#
# Epoch 00009: val_acc did not improve from 0.55695
# Epoch 10/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 201ms/step - loss: 1.2125 - acc: 0.5604 - val_loss: 1.4698 - val_acc: 0.5389
#
# Epoch 00010: val_acc did not improve from 0.55695
# Epoch 11/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 201ms/step - loss: 1.2030 - acc: 0.5667 - val_loss: 1.3869 - val_acc: 0.5444
#
# Epoch 00011: val_acc did not improve from 0.55695
# Epoch 12/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 201ms/step - loss: 1.2111 - acc: 0.5642 - val_loss: 1.2121 - val_acc: 0.5551
#
# Epoch 00012: val_acc did not improve from 0.55695
# Epoch 13/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 201ms/step - loss: 1.2088 - acc: 0.5647 - val_loss: 1.0498 - val_acc: 0.5414
#
# Epoch 00013: val_acc did not improve from 0.55695
# Epoch 14/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 201ms/step - loss: 1.2095 - acc: 0.5624 - val_loss: 1.3557 - val_acc: 0.5481
#
# Epoch 00014: val_acc did not improve from 0.55695
# Epoch 15/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 201ms/step - loss: 1.2043 - acc: 0.5664 - val_loss: 1.4641 - val_acc: 0.5320
#
# Epoch 00015: val_acc did not improve from 0.55695
# Epoch 16/100
# Learning rate:  0.001
# 897/897 [==============================] - 180s 201ms/step - loss: 1.2108 - acc: 0.5669 - val_loss: 0.8907 - val_acc: 0.5367
#
# Epoch 00016: val_acc did not improve from 0.55695
# Epoch 17/100
# Learning rate:  0.001
# 897/897 [==============================] - 181s 201ms/step - loss: 1.2077 - acc: 0.5617 - val_loss: 1.2480 - val_acc: 0.5397
#
# Epoch 00017: val_acc did not improve from 0.55695
# Epoch 18/100
# Learning rate:  0.001
# 315/897 [=========>....................] - ETA: 1:48 - loss: 1.2087 - acc: 0.5611

# %%
print(model_info.history.keys())

import matplotlib.pyplot as plt
plt.plot(model_info.history['loss'])
plt.plot(model_info.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
